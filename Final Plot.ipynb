# %%
import pandas as pd
import matplotlib.pyplot as plt

desired_initial_value = 100000
# Scale the list
## data_strategy_2_VAR_Sharpe
data_strategy_1 = [
        105000.000000, 102470.899670, 104729.210855, 103090.845189,
        111023.351227, 106898.545354, 101520.877195, 105392.583069, 98550.692840,
        98268.679501, 93901.026782, 97248.578527, 92486.780408, 85619.453713,
        89375.633171, 94398.486750, 90035.671747, 94952.365269, 89169.033746,
        95682.681746, 97224.396380, 98173.889164, 101787.561584, 104404.080744
    ]
data_strategy_3_svm = [
        105000.000000, 117121.723439, 122522.907697, 107068.394232,
        117508.780401, 122772.373530, 131750.456085, 154433.150461,
        148456.461942, 166994.860962, 133546.492651, 152845.287623,
        153370.531593, 140272.041964, 156448.371559, 158270.003917,
        140570.847757, 153131.714329, 151257.888301, 147030.532865,
        143691.386052, 139455.385135, 154077.209868, 164483.060691
    ]
data_strategy_3_clustering = [103157.657652, 121942.011146, 134812.589866, 130234.424457, 144483.930567,
              157770.110317, 169411.212452, 175301.609081, 171440.309743, 206181.388888,
              172508.605678, 186096.137813, 200330.907873, 198440.082499, 223533.067939,
              210885.592680, 190473.667236, 194606.607532, 180460.376653, 184998.926038,
              188299.186073, 170058.842801, 169942.971334, 178390.089697]
scale_factor = desired_initial_value / data_strategy_3_svm[0]
scale_factor_2 = desired_initial_value / data_strategy_3_clustering[0]


data_strategy_1 = [x * scale_factor for x in data_strategy_1]
data_strategy_3_svm = [x * scale_factor for x in data_strategy_3_svm]
data_strategy_3_clustering = [x * scale_factor_2 for x in data_strategy_3_clustering]

# Provided data points for the plots
data_strategy_2_VAR_Sharpe = {
    'Date': [
        '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
        '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01', '2022-05-01',
        '2022-06-01', '2022-07-01', '2022-08-01', '2022-09-01', '2022-10-01',
        '2022-11-01', '2022-12-01', '2023-01-01', '2023-02-01', '2023-03-01',
        '2023-04-01', '2023-05-01', '2023-06-01', '2023-07-01', '2023-08-01'
    ],
    'Total Wealth': [
        100000.000000, 96880.340461, 105641.755864, 108956.990501,
        121780.180054, 115866.739258, 112951.344270, 120059.441725,
        115056.456078, 110376.997220, 110695.028759, 118090.392392,
        115607.921058, 109483.713328, 116174.932704, 116388.546286,
        108954.383761, 110865.718009, 107840.604179, 116760.235823,
        118936.486258, 119803.447684, 122607.332189, 127103.067122
    ],
    'Label': 'Strategy 2: VAR + Sharpe'
}

data_strategy_1 = {
    'Date': [
        '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
        '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01', '2022-05-01',
        '2022-06-01', '2022-07-01', '2022-08-01', '2022-09-01', '2022-10-01',
        '2022-11-01', '2022-12-01', '2023-01-01', '2023-02-01', '2023-03-01',
        '2023-04-01', '2023-05-01', '2023-06-01', '2023-07-01', '2023-08-01'
    ],
    'Total Wealth': data_strategy_1,
    'Label': 'Strategy 1'
}

data_strategy_2_sample_mean_MVO = {
    'Date': ['2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01', '2022-01-01',
             '2022-02-01', '2022-03-01', '2022-04-01', '2022-05-01', '2022-06-01',
             '2022-07-01', '2022-08-01', '2022-09-01', '2022-10-01', '2022-11-01',
             '2022-12-01', '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
             '2023-05-01', '2023-06-01', '2023-07-01', '2023-08-01'],
    'Total Wealth': [100000.000000, 96541.768296, 103644.181179, 104389.007947, 112320.219352,
              107325.099405, 103863.882295, 107167.936340, 104512.839315, 99316.038205,
              97922.376386, 99564.553584, 95387.689696, 88701.755826, 90460.110325,
              98177.151131, 96484.539071, 95484.936193, 91799.497356, 101847.756614,
              106341.518946, 105380.276551, 108755.171745, 110799.625168],
    'Label': 'Strategy 2: Sample Mean + MVO'
}

data_strategy_2_OLS_Sharpe = {
    'Date': [
        '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
        '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01', '2022-05-01',
        '2022-06-01', '2022-07-01', '2022-08-01', '2022-09-01', '2022-10-01',
        '2022-11-01', '2022-12-01', '2023-01-01', '2023-02-01', '2023-03-01',
        '2023-04-01', '2023-05-01', '2023-06-01', '2023-07-01', '2023-08-01'
    ],
    'Total Wealth': [100000.000000, 96924.334322, 101623.587301, 101006.340521, 108513.384325,
              104236.806259, 99069.021280, 103561.732021, 96440.141590, 93894.443831,
              90417.134801, 95462.708257, 91681.598262, 85042.070731, 87812.585750,
              93305.366667, 88840.267236, 92772.737284, 88466.779488, 95682.438274,
              99163.128667, 101398.039606, 104546.821423, 107831.791100],
    'Label': 'Strategy 2: OLS + Sharpe'
}

data_strategy_3_clustering = {
     'Date': [
         '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
         '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01', '2022-05-01',
         '2022-06-01', '2022-07-01', '2022-08-01', '2022-09-01', '2022-10-01',
         '2022-11-01', '2022-12-01', '2023-01-01', '2023-02-01', '2023-03-01',
         '2023-04-01', '2023-05-01', '2023-06-01', '2023-07-01', '2023-08-01'
     ],
     'Total Wealth': data_strategy_3_clustering,
     'Label': 'Strategy 3: VAR + Sharpe + Clustering'
}

data_strategy_3_svm = {
    'Date': [
        '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
        '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01', '2022-05-01',
        '2022-06-01', '2022-07-01', '2022-08-01', '2022-09-01', '2022-10-01',
        '2022-11-01', '2022-12-01', '2023-01-01', '2023-02-01', '2023-03-01',
        '2023-04-01', '2023-05-01', '2023-06-01', '2023-07-01', '2023-08-01'
    ],
    'Total Wealth': data_strategy_3_svm,
    'Label': 'Strategy 3: SVM'
}

data_strategy_4_SVM_LASSO_RP = {
    'Date': [
        '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
        '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01', '2022-05-01',
        '2022-06-01', '2022-07-01', '2022-08-01', '2022-09-01', '2022-10-01',
        '2022-11-01', '2022-12-01', '2023-01-01', '2023-02-01', '2023-03-01',
        '2023-04-01', '2023-05-01', '2023-06-01', '2023-07-01', '2023-08-01'
    ],
    'Total Wealth': [100000.000000, 108676.473154, 112874.783061, 101160.757773, 111168.075289,
              115693.996764, 121235.791092, 138664.889490, 131963.711269, 144147.151271,
              119643.222177, 134509.370663, 134909.405370, 125407.791991, 138836.612978,
              141259.147181, 128180.857032, 140373.490715, 137976.307603, 134048.751803,
              131376.678229, 128335.346240, 140735.070946, 148962.704469],
    'Label': 'Strategy 4: SVM + LASSO + Risk Parity'
}

data_strategy_4_clustering_ols_sharpe_box = {
    'Date': [
        '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
        '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01', '2022-05-01',
        '2022-06-01', '2022-07-01', '2022-08-01', '2022-09-01', '2022-10-01',
        '2022-11-01', '2022-12-01', '2023-01-01', '2023-02-01', '2023-03-01',
        '2023-04-01', '2023-05-01', '2023-06-01', '2023-07-01', '2023-08-01'
    ],
    'Total Wealth': [
        100000.000000, 98808.867788, 105237.296334, 104315.851536,
        111359.962244, 107806.649598, 104750.480507, 109351.665884,
        102831.551123, 101334.281416, 99151.459655, 103628.720723,
        101762.580041, 97303.313630, 100123.911403, 106085.987534,
        103611.330288, 105189.080716, 101372.193137, 105169.822394,
        108021.485924, 106298.620531, 107507.155976, 108416.679851
    ],
    'Label': 'Strategy 4: Clustering + OLS + Sharpe_box'
}

data_russell_1000 = {
    'Date': [
        '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
        '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01', '2022-05-01',
        '2022-06-01', '2022-07-01', '2022-08-01', '2022-09-01', '2022-10-01',
        '2022-11-01', '2022-12-01', '2023-01-01', '2023-02-01', '2023-03-01',
        '2023-04-01', '2023-05-01', '2023-06-01', '2023-07-01', '2023-08-01'
    ],
    'Total Wealth': [
        100000.000000, 106851.083966, 105277.571452, 109418.318402,
        103162.734610, 100191.473150, 103437.743159, 94139.760558,
        93834.574670, 85848.746005, 93753.108978, 90004.384750,
        81561.605136, 88015.688986, 92596.031634, 87086.875099,
        92835.461413, 90471.684236, 93184.908746, 94251.827627,
        94520.213113, 100776.210847, 104146.128189, 102144.610336
    ],
    'Label': 'Russell 1000'
}

data_strategy_4_clustering_lasso_mvo_box = {
    'Date': [
        '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
        '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01', '2022-05-01',
        '2022-06-01', '2022-07-01', '2022-08-01', '2022-09-01', '2022-10-01',
        '2022-11-01', '2022-12-01', '2023-01-01', '2023-02-01', '2023-03-01',
        '2023-04-01', '2023-05-01', '2023-06-01', '2023-07-01', '2023-08-01'
    ],
    'Total Wealth': [
        100000.000000, 104107.546087, 111353.725559, 105543.124535,
        111355.353214, 106346.053482, 105451.987072, 110509.934923,
        101058.763322, 102161.562885, 94712.013765, 100575.977243,
        99033.698097, 93858.965742, 99173.247760, 102418.357647,
        96640.088519, 101387.634079, 95960.870362, 94406.828174,
        96332.341618, 93776.799849, 97058.141395, 99437.856126
    ],
    'Label': 'Strategy 4: Clustering + LASSO + MVO_box'
}

# Convert the date strings to datetime objects and create DataFrames
df1 = pd.DataFrame(data_strategy_1)
df1['Date'] = pd.to_datetime(df1['Date'])

df2 = pd.DataFrame(data_strategy_2_VAR_Sharpe)
df2['Date'] = pd.to_datetime(df2['Date'])

df3 = pd.DataFrame(data_strategy_2_OLS_Sharpe)
df3['Date'] = pd.to_datetime(df3['Date'])

df4 = pd.DataFrame(data_strategy_3_clustering)
df4['Date'] = pd.to_datetime(df4['Date'])

df5 = pd.DataFrame(data_strategy_3_svm)
df5['Date'] = pd.to_datetime(df5['Date'])

df6 = pd.DataFrame(data_strategy_4_SVM_LASSO_RP)
df6['Date'] = pd.to_datetime(df6['Date'])

df7 = pd.DataFrame(data_strategy_4_clustering_lasso_mvo_box)
df7['Date'] = pd.to_datetime(df7['Date'])

df8 = pd.DataFrame(data_russell_1000)
df8['Date'] = pd.to_datetime(df8['Date'])

df9 = pd.DataFrame(data_strategy_2_sample_mean_MVO)
df9['Date'] = pd.to_datetime(df2['Date'])
# Start plotting
plt.figure(figsize=(12, 6))

# Plot each line
plt.plot(df1['Date'], df1['Total Wealth'], label=df1['Label'].iloc[0], marker='o')
plt.plot(df9['Date'], df9['Total Wealth'], label=df9['Label'].iloc[0], marker='o')
plt.plot(df2['Date'], df2['Total Wealth'], label=df2['Label'].iloc[0], marker='o')
plt.plot(df3['Date'], df3['Total Wealth'], label=df3['Label'].iloc[0], marker='o')
plt.plot(df4['Date'], df4['Total Wealth'], label=df4['Label'].iloc[0], marker='o')
plt.plot(df5['Date'], df5['Total Wealth'], label=df5['Label'].iloc[0], marker='o')
plt.plot(df6['Date'], df6['Total Wealth'], label=df6['Label'].iloc[0], marker='o')
plt.plot(df7['Date'], df7['Total Wealth'], label=df7['Label'].iloc[0], marker='o')
plt.plot(df8['Date'], df8['Total Wealth'], label=df8['Label'].iloc[0], marker='o')


# Formatting the plot
plt.title('Portfolio Wealth Evolution')
plt.xlabel('Date')
plt.ylabel('Total Wealth')
plt.legend()
plt.grid(True)

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)
plt.tight_layout()
